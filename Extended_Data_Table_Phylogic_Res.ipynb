# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys

import random
import math
import dalmatian

# %% [markdown]
# ## Concatentate Phylogic outputs into one spreadsheet

# %% [markdown]
# ### Mut ccfs files

# %%
pat_1598 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598.mut_ccfs.txt", sep='\t')



pat_1078 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078.mut_ccfs.txt", sep='\t')


pat_1326 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity.mut_ccfs.txt", sep='\t')
pat_1644 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644.mut_ccfs.txt", sep='\t')

pat_2819 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819.mut_ccfs.txt", sep='\t',
                      low_memory=False)
pat_2389 = pd.read_csv("/Users/lmartin/Documents/2023/2389_multiple_6_bl_tree_0515/2389_multiple_6_bl_tree_v1/2389_multiple_6.mut_ccfs.txt", sep='\t',
                      low_memory=False)

pat_2974 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974.mut_ccfs.txt", sep='\t')

pat_1035 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035.mut_ccfs.txt", sep='\t')

pat_1002 = pd.read_csv('~/Documents/2020/new_pon_breast_phylo/1002_pre_post_updated/1002_with_pre_post.mut_ccfs.txt',sep='\t',
                          low_memory=False)
pat_1534 = pd.read_csv('~/Documents/2024/RA_1534_vm_new_bams/RA_1534_bl_TBX/1534_bl_TBX/1534.mut_ccfs.txt',sep='\t')

pat_1547 = pd.read_csv('~/Documents/2020/new_pon_breast_phylo/1547_0915/1547_newer_bl_tree/1547.mut_ccfs.txt',sep='\t',
                          low_memory=False)

pat_1558 = pd.read_csv('~/Documents/2023/RA_1558_fix_pies/take_3/1558_fix_pies_v3/1558.mut_ccfs.txt',sep='\t')

pat_2542 = pd.read_csv('~/Documents/2023/RA_2542_PIK3CA/2542_high_purity_v6_morebl_moreiter_results/2542_high_purity_v6_morebl_moreiter.mut_ccfs.txt',sep='\t')

pat_1045 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045.mut_ccfs.txt",sep='\t',low_memory=False)

pat_1113 =pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113.mut_ccfs.txt",sep='\t')

pats_list = [pat_1002, pat_1547, pat_1598, pat_1078, pat_1045, pat_1113, pat_2389,
            pat_1326, pat_1644, pat_2819, pat_2974, pat_1035, pat_1534, pat_1558, pat_2542]

# %%
len(pats_list)
# Out:
# 15

# %%
mut_ccfs_df = pd.concat(pats_list)

# %% [markdown]
# ## Mutational signature output file

# %%
signatures = pd.read_csv('/Users/lmartin/Documents/2024/031924_CDK4_sigs_cosmic2_diff2542/autopsy_with_cosmic2_sigs_031924.tsv',sep='\t')

# %% [markdown]
# ### Cluster ccfs files

# %%
pat_1002_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_pre_post_updated/1002_with_pre_post.cluster_ccfs.txt", sep='\t',
                      low_memory=False)

pat_1598_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598.cluster_ccfs.txt", sep='\t')



pat_1078_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078.cluster_ccfs.txt", sep='\t')


pat_1326_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity.cluster_ccfs.txt", sep='\t')
pat_1644_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644.cluster_ccfs.txt", sep='\t')

pat_2819_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819.cluster_ccfs.txt", sep='\t',
                      low_memory=False)

pat_2389_cluster = pd.read_csv("/Users/lmartin/Documents/2023/2389_multiple_6_bl_tree_0515/2389_multiple_6_bl_tree_v1/2389_multiple_6.cluster_ccfs.txt", sep='\t')

pat_2974_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974.cluster_ccfs.txt", sep='\t')

pat_1035_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035.cluster_ccfs.txt", sep='\t')


pat_1534_cluster = pd.read_csv('~/Documents/2024/RA_1534_vm_new_bams/RA_1534_bl_TBX/1534_bl_TBX/1534.cluster_ccfs.txt',sep='\t')

pat_1547_cluster = pd.read_csv('~/Documents/2020/new_pon_breast_phylo/1547_0915/1547_newer_bl_tree/1547.cluster_ccfs.txt',sep='\t',
                          low_memory=False)

pat_1558_cluster = pd.read_csv('~/Documents/2023/RA_1558_fix_pies/take_3/1558_fix_pies_v3/1558.cluster_ccfs.txt',sep='\t')

pat_2542_cluster = pd.read_csv('~/Documents/2023/RA_2542_PIK3CA/2542_high_purity_v6_morebl_moreiter_results/2542_high_purity_v6_morebl_moreiter.cluster_ccfs.txt',sep='\t')

pat_1045_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045.cluster_ccfs.txt",sep='\t')

pat_1113_cluster = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113.cluster_ccfs.txt",sep='\t')


pats_cluster_ccfs_list = [pat_1002_cluster, pat_1598_cluster, pat_1078_cluster, pat_1045_cluster, pat_1113_cluster,
            pat_1326_cluster, pat_1644_cluster, pat_2819_cluster, pat_2389_cluster, pat_2974_cluster, pat_1035_cluster, pat_1534_cluster,
                         pat_1547_cluster,pat_1558_cluster, pat_2542_cluster]

cluster_ccfs_df=pd.concat(pats_cluster_ccfs_list)

# %%
len(pats_cluster_ccfs_list)
# Out:
# 15

# %%
pat_1113_cluster
# Out:
#     Patient_ID  Sample_ID  Sample_Alias  Cluster_ID  postDP_ccf_mean  \
# 0         1113          1           NaN           1             1.00
# 1         1113          2           NaN           1             0.94
# 2         1113          3           NaN           1             1.00
# 3         1113          4           NaN           1             1.00
# 4         1113          5           NaN           1             1.00
# ..         ...        ...           ...         ...              ...
# 60        1113          1           NaN          13             0.15
# 61        1113          2           NaN          13             0.02
# 62        1113          3           NaN          13             0.01
# 63        1113          4           NaN          13             0.01
# 64        1113          5           NaN          13             0.01
#
#     postDP_ccf_CI_low  postDP_ccf_CI_high  postDP_ccf_0.0  postDP_ccf_0.01  \
# ...

# %% [markdown]
# ### Buildtree Posteriors

# %%
def insert_pat_col(input_df, pat_id):
    patient_ID_col = [pat_id]*len(input_df)
    input_df.insert(loc=0,column='Patient_ID',value=patient_ID_col)
    return input_df

# %%
pat_1002_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_updated_apr21/1002_with_pre_post_build_tree_posteriors.tsv", sep='\t')
pat_1002_buildtree_add_pat = insert_pat_col(pat_1002_buildtree,'1002')

pat_1547_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1547_0915/1547_newer_bl_tree/1547_build_tree_posteriors.tsv", sep='\t')
pat_1547_buildtree_add_pat = insert_pat_col(pat_1547_buildtree,'1547')

pat_1078_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078_build_tree_posteriors.tsv", sep='\t')
pat_1078_buildtree_add_pat = insert_pat_col(pat_1078_buildtree,'1078')

pat_1598_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598_build_tree_posteriors.tsv", sep='\t')
pat_1598_buildtree_add_pat = insert_pat_col(pat_1598_buildtree,'1598')

pat_1326_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity_build_tree_posteriors.tsv", sep='\t')
pat_1326_buildtree_add_pat = insert_pat_col(pat_1326_buildtree,'1326')

pat_1644_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644_build_tree_posteriors.tsv", sep='\t')
pat_1644_buildtree_add_pat = insert_pat_col(pat_1644_buildtree,'1644')

pat_2819_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819_build_tree_posteriors.tsv", sep='\t')
pat_2819_buildtree_add_pat = insert_pat_col(pat_2819_buildtree,'2819')

pat_2389_buildtree = pd.read_csv("/Users/lmartin/Documents/2023/2389_multiple_6_bl_tree_0515/2389_multiple_6_bl_tree_v1/2389_multiple_6_build_tree_posteriors.tsv", sep='\t')
pat_2389_buildtree_add_pat = insert_pat_col(pat_2389_buildtree,'2389')

pat_2974_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974_build_tree_posteriors.tsv", sep='\t')
pat_2974_buildtree_add_pat = insert_pat_col(pat_2974_buildtree,'2974')

pat_1534_buildtree = pd.read_csv("/Users/lmartin/Documents/2024/RA_1534_vm_new_bams/RA_1534_bl_TBX/1534_bl_TBX/1534_build_tree_posteriors.tsv", sep='\t')
pat_1534_buildtree_add_pat = insert_pat_col(pat_1534_buildtree,'1534')

pat_1035_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035_build_tree_posteriors.tsv", sep='\t')
pat_1035_buildtree_add_pat = insert_pat_col(pat_1035_buildtree,'1035')

pat_1113_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113_build_tree_posteriors.tsv", sep='\t')
pat_1113_buildtree_add_pat = insert_pat_col(pat_1113_buildtree,'1113')

pat_1045_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045_build_tree_posteriors.tsv", sep='\t')
pat_1045_buildtree_add_pat = insert_pat_col(pat_1045_buildtree,'1045')

pat_1558_buildtree = pd.read_csv("/Users/lmartin/Documents/2023/RA_1558_fix_pies/take_3/1558_fix_pies_v3/1558_build_tree_posteriors.tsv", sep='\t')
pat_1558_buildtree_add_pat = insert_pat_col(pat_1558_buildtree,'1558')

pat_2542_buildtree = pd.read_csv('~/Documents/2023/RA_2542_PIK3CA/2542_high_purity_v6_morebl_moreiter_results/2542_high_purity_v6_morebl_moreiter_build_tree_posteriors.tsv',sep='\t')
pat_2542_buildtree_add_pat = insert_pat_col(pat_2542_buildtree,'2542')

buildtrees=[pat_1078_buildtree_add_pat,pat_1598_buildtree_add_pat,pat_1326_buildtree_add_pat,pat_1644_buildtree_add_pat,
            pat_2819_buildtree_add_pat,pat_2389_buildtree_add_pat,pat_2974_buildtree_add_pat,pat_1534_buildtree_add_pat,
            pat_1035_buildtree_add_pat,pat_1113_buildtree_add_pat,pat_1045_buildtree_add_pat,
           pat_1558_buildtree_add_pat,pat_2542_buildtree_add_pat]

buildtree_df = pd.concat(buildtrees)
buildtree_df
# Out:
#    Patient_ID  n_iter                                         likelihood  \
# 0        1078     286  [0.33333333333333337, 0.3333333333333332, 0.33...
# 1        1078     270  [0.5, 0.33333333333333331, 0.3333333333333332,...
# 2        1078     234  [0.3333333333333332, 0.5, 0.5, 0.3333333333333...
# 3        1078     209  [0.19999999999999998, 0.5, 0.19999999999999998...
# 0        1598      28  [0.14285714285714157, 0.24999999999999906, 0.4...
# ..        ...     ...                                                ...
# 38       2542       1                              [0.24999999999999906]
# 39       2542       1                              [0.19999999999999943]
# 40       2542       1                              [0.19999999999999943]
# 41       2542       1                              [0.19999999999999943]
# 42       2542       1                              [0.24999999999999906]
#
#                                                 edges
# ...

# %% [markdown]
# ## cell populations

# %%
pat_1002_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_updated_apr21/1002_with_pre_post_cell_population_abundances.tsv", sep='\t')

pat_1547_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1547_0915/1547_newer_bl_tree/1547_cell_population_abundances.tsv", sep='\t')

pat_1078_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078_cell_population_abundances.tsv", sep='\t')
pat_1598_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598_cell_population_abundances.tsv", sep='\t')

pat_1326_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity_cell_population_abundances.tsv", sep='\t')
pat_1644_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644_cell_population_abundances.tsv", sep='\t')

pat_2819_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819_cell_population_abundances.tsv", sep='\t')
pat_2389_cellpop = pd.read_csv("/Users/lmartin/Documents/2023/2389_multiple_6_bl_tree_0515/2389_multiple_6_bl_tree_v1/2389_multiple_6_cell_population_abundances.tsv", sep='\t')

pat_2974_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974_cell_population_abundances.tsv", sep='\t')
pat_1534_cellpop = pd.read_csv("/Users/lmartin/Documents/2024/RA_1534_vm_new_bams/RA_1534_bl_TBX/1534_bl_TBX/1534_cell_population_abundances.tsv", sep='\t')

pat_1035_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035_cell_population_abundances.tsv", sep='\t')

pat_1113_cellpop = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113_cell_population_abundances.tsv',sep='\t')
pat_1045_cellpop = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045_cell_population_abundances.tsv',sep='\t')

pat_1558_cellpop = pd.read_csv("/Users/lmartin/Documents/2023/RA_1558_fix_pies/take_3/1558_fix_pies_v3/1558_cell_population_abundances.tsv", sep='\t')


pat_2542_cellpop = pd.read_csv('~/Documents/2023/RA_2542_PIK3CA/2542_high_purity_v6_morebl_moreiter_results/2542_high_purity_v6_morebl_moreiter_cell_population_abundances.tsv',sep='\t')



cellpops=[pat_1002_cellpop,pat_1547_cellpop,pat_1078_cellpop,pat_1598_cellpop,pat_1326_cellpop,pat_1644_cellpop,pat_2819_cellpop,
         pat_2389_cellpop,pat_2974_cellpop,pat_1534_cellpop,pat_1035_cellpop,pat_1113_cellpop,
         pat_1045_cellpop,pat_1558_cellpop,pat_2542_cellpop]


cellpop_df = pd.concat(cellpops)
cellpop_df
# Out:
#                              Patient_ID Sample_ID  \
# 0                    1002_with_pre_post       pre
# 1                    1002_with_pre_post       pre
# 2                    1002_with_pre_post       pre
# 3                    1002_with_pre_post       pre
# 4                    1002_with_pre_post       pre
# ..                                  ...       ...
# 75  2542_high_purity_v6_morebl_moreiter   2542_13
# 76  2542_high_purity_v6_morebl_moreiter   2542_13
# 77  2542_high_purity_v6_morebl_moreiter   2542_13
# 78  2542_high_purity_v6_morebl_moreiter   2542_13
# 79  2542_high_purity_v6_morebl_moreiter   2542_13
#
#                   Cell_population  Cell_abundance
# 0                             CL1              78
# 1                         CL1_CL5               0
# 2                         CL1_CL6              18
# 3                     CL1_CL5_CL8               0
# 4                    CL1_CL6_CL10               0
# ..                            ...             ...
# ...

# %%
pat_1002_cellpop
# Out:
#              Patient_ID    Sample_ID        Cell_population  Cell_abundance
# 0    1002_with_pre_post          pre                    CL1              78
# 1    1002_with_pre_post          pre                CL1_CL5               0
# 2    1002_with_pre_post          pre                CL1_CL6              18
# 3    1002_with_pre_post          pre            CL1_CL5_CL8               0
# 4    1002_with_pre_post          pre           CL1_CL6_CL10               0
# ..                  ...          ...                    ...             ...
# 325  1002_with_pre_post  cfDNA_10351           CL1_CL5_CL16               7
# 326  1002_with_pre_post  cfDNA_10351       CL1_CL5_CL8_CL17               1
# 327  1002_with_pre_post  cfDNA_10351               CL1_CL18               1
# 328  1002_with_pre_post  cfDNA_10351      CL1_CL5_CL16_CL19               1
# 329  1002_with_pre_post  cfDNA_10351  CL1_CL5_CL8_CL14_CL20               0
#
# [330 rows x 4 columns]

# %% [markdown]
# ## Absolute CN by sample

# %%
## current best file found needs added samples / patients

# %%
absolute_cn = pd.read_csv('/Users/lmartin/Documents/2020/autopsy_copy_number/all_cdk4_add_1035_igv.seg',sep='\t')
absolute_cn
# Out:
#             Sample  Chromosome  Start Position  End Position      Start  \
# 0         T01027-3           1           12176      94643659      12176
# 1         T01027-3           1        94645397     104160689   94645397
# 2         T01027-3           1       107599965     144363924  107599965
# 3         T01027-3           1       144520739     147131922  144520739
# 4         T01027-3           1       147142061     147380734  147142061
# ...            ...         ...             ...           ...        ...
# 18558  1035_20.tsv          21         9907370      31874299    9907370
# 18559  1035_20.tsv          21        31914039      48084246   31914039
# 18560  1035_20.tsv          22        16287569      21567422   16287569
# 18561  1035_20.tsv          22        21579761      25007131   21579761
# 18562  1035_20.tsv          22        25019815      51237388   25019815
#
#              End  Num_Probes    Seg_CN
# 0       94643659        7210  0.000000
# ...

# %% [markdown]
# ## Mutsig

# %% [markdown]
# ### mutsig on pats

# %%
patients_sig_genes = pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/on_patients_v3/0/mutsig_results/outdir/sig_genes.txt',sep='\t')

patients_counts_and_rates = pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/on_patients_v3/0/mutsig_results/outdir/patient_counts_and_rates.txt',sep='\t')

# %% [markdown]
# ### mutsig on clones

# %%
clones_sig_genes = pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/on_clones_v3/0/mutsig_results/outdir/sig_genes.txt',sep='\t')
clones_sig_genes.head(10)
# Out:
#        gene                                           longname  codelen  nnei  \
# 0    PIK3CA  phosphoinositide-3-kinase, catalytic, alpha po...     3283    70
# 1      ESR1                                estrogen receptor 1     1901    48
# 2     KMT2C       myeloid/lymphoid or mixed-lineage leukemia 3    15143    46
# 3      TP53                                  tumor protein p53     1422    42
# 4      KRAS  v-Ki-ras2 Kirsten rat sarcoma viral oncogene h...      727   167
# 5    CTNNA2     catenin (cadherin-associated protein), alpha 2     3166    43
# 6      MNDA       myeloid cell nuclear differentiation antigen     1248   240
# 7  HIST1H3B                             histone cluster 1, H3b      413   224
# 8      ST18  suppression of tumorigenicity 18 (breast carci...     3221    72
# 9  C12orf61                chromosome 12 open reading frame 61      396    31
#
#    nncd  nsil  nmis  nstp  nspl  nind  ...  npat  nsite           pCV  \
# ...

# %% [markdown]
# ### mutsig on subclones

# %%
subclones_sig_genes = pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/on_subclones_v3/0/mutsig_results/outdir/sig_genes.txt',sep='\t')

# %%
subclones_sig_genes.head(10)
# Out:
#        gene                                           longname  codelen  nnei  \
# 0      ESR1                                estrogen receptor 1     1901    48
# 1     KMT2C       myeloid/lymphoid or mixed-lineage leukemia 3    15143    51
# 2      TP53                                  tumor protein p53     1422    42
# 3      KRAS  v-Ki-ras2 Kirsten rat sarcoma viral oncogene h...      727   174
# 4    PIK3CA  phosphoinositide-3-kinase, catalytic, alpha po...     3283    71
# 5      MNDA       myeloid cell nuclear differentiation antigen     1248   240
# 6    CTNNA2     catenin (cadherin-associated protein), alpha 2     3166    23
# 7  HIST1H3B                             histone cluster 1, H3b      413   224
# 8      CSAD               cysteine sulfinic acid decarboxylase     1629    95
# 9      ST18  suppression of tumorigenicity 18 (breast carci...     3221    72
#
#    nncd  nsil  nmis  nstp  nspl  nind  ...  npat  nsite           pCV  \
# ...

# %% [markdown]
# ## clonesig results

# %%
clonesig_res =  pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/curveball_on_clones_with_mutsig_100923.tsv',sep='\t',index_col=0)
clonesig_res
# Out:
#         gene       p         q      MutSig_q    MutSig_qCV    log10q
# 2      KMT2C  0.0062  0.080600  2.446563e-06  1.417806e-07  1.093665
# 7   HIST1H3B  0.0139  0.090350  2.225623e-01  8.444213e-02  1.044072
# 11       FLG  0.0230  0.099667  1.000000e+00  3.373967e-01  1.001450
# 8       ST18  0.1289  0.359320  3.266516e-01  1.000000e+00  0.444519
# 3       TP53  0.1382  0.359320  2.459710e-03  7.577841e-04  0.444519
# 1       ESR1  0.2142  0.464100  9.083234e-12  1.557390e-07  0.333388
# 12      CLP1  0.2763  0.513129  1.000000e+00  4.991518e-01  0.289774
# 4       KRAS  0.3318  0.539175  4.582945e-02  2.934754e-01  0.268270
# 9      KLK13  0.4980  0.648440  1.000000e+00  2.934754e-01  0.188130
# 10    ADAM19  0.4988  0.648440  1.000000e+00  2.934754e-01  0.188130
# 6       MNDA  0.6242  0.698425  1.625311e-01  3.417281e-01  0.155880
# 5     CTNNA2  0.6447  0.698425  1.625311e-01  1.000000e+00  0.155880
# 0     PIK3CA  0.8864  0.886400  1.818100e-12  4.291167e-10  0.052370

# %%
only_clonesig = pd.read_csv('/Users/lmartin/Documents/2023/CDK4_mutsig_added_pats/curveball_on_clones.tsv',sep='\t')

# %% [markdown]
# ## pre post mutsig on samples res

# %%
prepost_mutsig_res = pd.read_csv('/Users/lmartin/Documents/2024/CDK4_Pre_Post_Sample_Comut/PrePost_Mutsig/mutsig_results_pats_remove_junk1/outdir/sig_genes.txt',sep='\t')
prepost_mutsig_res.head(5)
# Out:
#     gene                                     longname  codelen  nnei  nncd  \
# 0   ESR1                          estrogen receptor 1     1901   152     0
# 1   CDH1  cadherin 1, type 1, E-cadherin (epithelial)     2709    45     0
# 2  GATA3                       GATA binding protein 3     1351    31     0
# 3   TP53                            tumor protein p53     1422    28     1
# 4   NAV1                           neuron navigator 1     5848    46     1
#
#    nsil  nmis  nstp  nspl  nind  ...  npat  nsite           pCV       pCL  \
# 0     0    10     0     0     0  ...     8      4  6.948777e-09  0.000003
# 1     0     1     1     0     3  ...     5      5  6.672233e-07  0.007700
# 2     1     1     0     0     4  ...     5      5  1.157737e-07  1.000000
# 3     0     6     0     1     1  ...     6      8  2.993179e-06  1.000000
# 4     5     2     0     0     2  ...     4      3  5.111528e-03  0.002450
#
#         pFN      pCL2      pFN2  pCF             p             q
# ...

# %% [markdown]
# ## write all results to one spreadsheet

# %%
with pd.ExcelWriter('Extended_Data_Table2_Phylogic.xlsx') as writer:  
    #mut_ccfs_df.to_excel(writer, sheet_name='Phylogic MutCCFs')
    cluster_ccfs_df.to_excel(writer, sheet_name='Phylogic ClusterCCFs')
    buildtree_df.to_excel(writer, sheet_name='BuildTree Posteriors')
    cellpop_df.to_excel(writer, sheet_name='Cell Populations')
    absolute_cn.to_excel(writer, sheet_name='Sample_CNV')
    patients_sig_genes.to_excel(writer, sheet_name='Mutsig_Patients')
    clones_sig_genes.to_excel(writer, sheet_name='Mutsig_Clones')
    subclones_sig_genes.to_excel(writer, sheet_name='Mutsig_Subclones')
    clonesig_res.to_excel(writer, sheet_name='CloneSig')
    prepost_mutsig_res.to_excel(writer, sheet_name='PrePost_Mutsig')

# %% [markdown]
# ## write results without the mutation files because those are big
