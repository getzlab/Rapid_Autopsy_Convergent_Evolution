# %%
import matplotlib.pyplot as plt
import seaborn as sea
import pandas as pd
import numpy as np
import seaborn as sns
import sys

import random
import math
import dalmatian

# %% [markdown]
# ## Concatentate BuildTree Posteriors and Cell Popuations into one spreadsheet

# %%
pat_1002 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002.mut_ccfs.txt", sep='\t')

pat_1547 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1547_passed_muts_results/1547.mut_ccfs.txt", sep='\t')

pat_1078 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078.mut_ccfs.txt", sep='\t')
pat_1598 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598.mut_ccfs.txt", sep='\t')

pat_1326 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity.mut_ccfs.txt", sep='\t')
pat_1644 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644.mut_ccfs.txt", sep='\t')

pat_2819 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819.mut_ccfs.txt", sep='\t')
pat_2389 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2389_passed_muts_results/2389.mut_ccfs.txt", sep='\t')

pat_2974 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974.mut_ccfs.txt", sep='\t')
pat_1534 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1534_no_norm.mut_ccfs.txt", sep='\t')

pat_1035 = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035.mut_ccfs.txt", sep='\t')


pat_1113 = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113.mut_ccfs.txt',sep='\t')
pat_1045 = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045.mut_ccfs.txt',sep='\t')

# %% [markdown]
# ## Buildtree Posteriors

# %%
def insert_pat_col(input_df, pat_id):
    patient_ID_col = [pat_id]*len(input_df)
    input_df.insert(loc=0,column='Patient_ID',value=patient_ID_col)
    return input_df

# %%
pat_1002_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1002_buildtree_add_pat = insert_pat_col(pat_1002_buildtree,'1002')

pat_1547_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1547_buildtree_add_pat = insert_pat_col(pat_1078_buildtree,'1547')

pat_1078_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1078_buildtree_add_pat = insert_pat_col(pat_1078_buildtree,'1078')

pat_1598_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1598_buildtree_add_pat = insert_pat_col(pat_1002_buildtree,'1598')

pat_1326_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1326_buildtree_add_pat = insert_pat_col(pat_1002_buildtree,'1326')

pat_1644_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1644_buildtree_add_pat = insert_pat_col(pat_1002_buildtree,'1644')

pat_2819_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_2819_buildtree_add_pat = insert_pat_col(pat_2819_buildtree,'2819')

pat_2389_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_2389_buildtree_add_pat = insert_pat_col(pat_2389_buildtree,'2389')

pat_2974_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_2974_buildtree_add_pat = insert_pat_col(pat_2974_buildtree,'2974')

pat_1534_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1534_buildtree_add_pat = insert_pat_col(pat_2819_buildtree,'1534')

pat_1035_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1035_buildtree_add_pat = insert_pat_col(pat_1035_buildtree,'1035')

pat_1113_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1113_buildtree_add_pat = insert_pat_col(pat_1113_buildtree,'1113')

pat_1045_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1045_buildtree_add_pat = insert_pat_col(pat_1045_buildtree,'1045')

pat_1558_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_1558_buildtree_add_pat = insert_pat_col(pat_1558_buildtree,'1558')

pat_2542_buildtree = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_build_tree_posteriors.tsv", sep='\t')
pat_2542_buildtree_add_pat = insert_pat_col(pat_2542_buildtree,'2542')

buildtrees=[pat_1078_buildtree_add_pat,pat_1598_buildtree_add_pat,pat_1326_buildtree_add_pat,pat_1644_buildtree_add_pat,
            pat_2819_buildtree_add_pat,pat_2389_buildtree_add_pat,pat_2974_buildtree_add_pat,pat_1534_buildtree_add_pat,
            pat_1035_buildtree_add_pat,pat_1113_buildtree_add_pat,pat_1045_buildtree_add_pat]

buildtree_df = pd.concat(buildtrees)
buildtree_df

# %% [markdown]
# ## cell populations

# %%
#pat_1002_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1002_bl_tree/1002_cell_population_abundances.tsv", sep='\t')

#pat_1547_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1547_passed_muts_results/1547.mut_ccfs.txt", sep='\t')

pat_1078_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1078_new_pon_results/1078_cell_population_abundances.tsv", sep='\t')
pat_1598_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1598_new_pon_results/1598_cell_population_abundances.tsv", sep='\t')

pat_1326_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1326_firecloud_phylo/1326_cfDNA_high_purity_cell_population_abundances.tsv", sep='\t')
pat_1644_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1644_passed_muts_results/1644_cell_population_abundances.tsv", sep='\t')

pat_2819_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2819_passed_muts_results/2819_cell_population_abundances.tsv", sep='\t')
pat_2389_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2389_passed_muts_results/2389_cell_population_abundances.tsv", sep='\t')

pat_2974_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/2974_new_pon_results/2974_cell_population_abundances.tsv", sep='\t')
pat_1534_cellpop = pd.read_csv("/Users/lmartin/Documents/2023/RA_1534_rerun_phylogic/1534_phylo_120423/1534_cell_population_abundances.tsv", sep='\t')

pat_1035_cellpop = pd.read_csv("/Users/lmartin/Documents/2020/new_pon_breast_phylo/1035_with_indel/1035_cell_population_abundances.tsv", sep='\t')

pat_1113_cellpop = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1113_vm_phylo_results/1113_cell_population_abundances.tsv',sep='\t')
pat_1045_cellpop = pd.read_csv('/Users/lmartin/Documents/2020/new_pon_breast_phylo/1045_vm_phylo_results/1045_cell_population_abundances.tsv',sep='\t')

cellpops=[pat_1078_cellpop,pat_1598_cellpop,pat_1326_cellpop,pat_1644_cellpop,pat_2819_cellpop,
         pat_2389_cellpop,pat_2974_cellpop,pat_1534_cellpop,pat_1035_cellpop,pat_1113_cellpop,
         pat_1045_cellpop]

cellpop_df = pd.concat(cellpops)
cellpop_df
# Out:
#     Patient_ID   Sample_ID       Cell_population  Cell_abundance
# 0         1078          10                   CL1               0
# 1         1078          10               CL1_CL2               0
# 2         1078          10           CL1_CL2_CL3              98
# 3         1078          10           CL1_CL2_CL4               1
# 4         1078          10           CL1_CL2_CL5               1
# ..         ...         ...                   ...             ...
# 325       1045  cfDNA_2971      CL1_CL2_CL3_CL11               0
# 326       1045  cfDNA_2971      CL1_CL2_CL3_CL12               1
# 327       1045  cfDNA_2971      CL1_CL2_CL3_CL13               1
# 328       1045  cfDNA_2971  CL1_CL2_CL3_CL9_CL14              10
# 329       1045  cfDNA_2971      CL1_CL2_CL3_CL15               1
#
# [1454 rows x 4 columns]

# %% [markdown]
# ## write all results to one spreadsheet

# %%
with pd.ExcelWriter('Extended_Data_Table2_Phylogic.xlsx') as writer:  
    mutccfs_df.to_excel(writer, sheet_name='Phylogic MutCCFs')
    clusterccfs_df.to_excel(writer, sheet_name='Phylogic ClusterCCFs')
    buildtree_df.to_excel(writer, sheet_name='BuildTree Posteriors')
    cellpop_df.to_excel(writer, sheet_name='Cell Populations')
